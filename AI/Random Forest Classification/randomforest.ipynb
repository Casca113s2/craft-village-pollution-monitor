# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree
from sklearn.datasets import load_iris
import random
import math

# %%
data = pd.read_excel('data1.xlsx')
data.head()
# Out:
#    soil_pollution  air_pollution  water_pollution  Lượng khí ga đã sử dụng  \
# 0               1              1                0                    0.500
# 1               0              0                0                    0.987
# 2               0              0                1                    0.000
# 3               0              1                1                    1.500
# 4               1              1                1                   29.300
#
#    Lượng than đã sử dụng  Đốt cháy  Sử dụng khí ga  Sử dụng than  Sử dụng dầu  \
# 0                    0.0       0.3               1             2            2
# 1                    1.1       0.9               2             2            2
# 2                    0.0       0.2               2             2            2
# 3                   21.3       1.3               1             1            1
# 4                    5.4       6.1               1             1            1
#
# ...

# %%
X = data.drop(columns=['soil_pollution', 'air_pollution', 'water_pollution'])
y = data.loc[:, 'soil_pollution':'water_pollution']

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_test
# Out:
#       Lượng khí ga đã sử dụng  Lượng than đã sử dụng  Đốt cháy  \
# 9571                      0.0                    0.2       0.5
# 9502                      0.8                    0.6       0.3
# 3379                      3.6                   13.6      11.1
# 5407                      0.8                    0.9       0.3
# 7815                      0.7                    0.7       0.0
# ...                       ...                    ...       ...
# 3317                      1.0                    0.7       0.2
# 9283                     15.1                   10.6       9.7
# 6560                     12.6                   16.1       2.3
# 3055                      0.6                    0.4       0.4
# 759                      10.9                   26.9      10.4
#
#       Sử dụng khí ga  Sử dụng than  Sử dụng dầu  \
# 9571               2             2            1
# 9502               2             2            2
# 3379               1             1            2
# ...

# %%
# y_pred

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# Tạo một bộ Random Forest với 100 cây quyết định
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Huấn luyện mô hình trên tập dữ liệu huấn luyện
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Hiển thị độ quan trọng của các thuộc tính
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(20,10))
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), X.columns[indices], rotation=90)
plt.show()

# %%
# Hiển thị một cây quyết định ngẫu nhiên từ Random Forest
plt.figure(figsize=(50,25))
tree.plot_tree(rf.estimators_[0], feature_names=X.columns, class_names=y.columns, filled=True)
plt.show()

# %%
# Predict on test data
y_pred = rf.predict(X_test)

# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
x_new = np.array([0, 0, 0, 2, 2, 2, 25.4, 2, 1.3, 7.4, 0.9, 2, 0.8, 0.8, 0.6, 54.8, 38.5, 51.1])
feature_names = ["Lượng khí ga đã sử dụng", "Lượng than đã sử dụng", "Đốt cháy", "Sử dụng khí ga", "Sử dụng than", "Sử dụng dầu", "Tỷ lệ nước thải được thu gom và xử lý tại nhà máy", "Có nhà máy xử lý nước thải nào tại xã không?", "Lượng dầu đã sử dụng", "Lượng nước đầu vào", "Lượng chất thải rắn đã sử dụng", "Sử dụng chất thải rắn làm nhiên liệu", "Tỷ lệ không được thu gom", "Tỷ lệ được thu mua", "Lượng chất thải sinh hoạt trung bình của hộ gia đình", "Tỷ lệ: tái chế", "Tỷ lệ: bãi rác tập trung", "Tỷ lệ: bãi rác địa phương"]
df = pd.DataFrame(data=x_new.reshape(1, -1), columns=feature_names)
prediction = rf.predict(df)
output = prediction.tolist()
print(prediction)
# Out:
# [[0 0 1]]

# %%
pip install joblib==1.1.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
# ...

# %%
from joblib import dump
# Export models
dump(rf, 'random_forest.joblib')
# Out:
# ['random_forest.joblib']
